# %%
import numpy as np
import pandas as pd
import random

# %%
from PredictXANES import xanes_averaging
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-23999e90db64> in <module>
# ----> 1 from PredictXANES import xanes_averaging
#
# ModuleNotFoundError: No module named 'PredictXANES'

# %%
mu_cn_averaged, systems_averaged, weights_averaged = xanes_averaging.xanes_average(10000, '/Users/xinyuewang/Desktop/capstone/Data/XANES_ML_Data.xlsx', 10)

# %%
mu_cn_averaged
# Out:
#             CN       Mu1       Mu2       Mu3       Mu4       Mu5       Mu6  \
# 0     9.243099  0.030473  0.032903  0.035245  0.037608  0.040101  0.042833
# 1     8.878486  0.031299  0.033874  0.036348  0.038843  0.041478  0.044374
# 2     9.660656  0.030221  0.032635  0.034959  0.037300  0.039766  0.042462
# 3     9.374240  0.030615  0.033083  0.035458  0.037851  0.040373  0.043134
# 4     9.024108  0.030490  0.032911  0.035248  0.037609  0.040103  0.042839
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  9.387385  0.030622  0.033103  0.035489  0.037892  0.040424  0.043201
# 9996  9.813709  0.030216  0.032640  0.034969  0.037310  0.039771  0.042456
# 9997  8.976106  0.030995  0.033457  0.035838  0.038250  0.040803  0.043609
# 9998  9.812948  0.030522  0.032961  0.035309  0.037676  0.040168  0.042895
# 9999  9.001214  0.030867  0.033368  0.035775  0.038203  0.040765  0.043579
#
#            Mu7       Mu8       Mu9  ...      Mu91      Mu92      Mu93  \
# 0     0.045913  0.049450  0.053553  ...  1.007193  1.006658  1.006178
# 1     0.047651  0.051430  0.055832  ...  1.006492  1.006398  1.006341
# 2     0.045497  0.048976  0.053008  ...  0.998193  0.999098  1.000191
# 3     0.046247  0.049822  0.053970  ...  0.999501  1.001009  1.002750
# 4     0.045926  0.049473  0.053587  ...  1.018665  1.015530  1.012254
# ...        ...       ...       ...  ...       ...       ...       ...
# 9995  0.046334  0.049936  0.054122  ...  1.007119  1.005455  1.003816
# 9996  0.045473  0.048929  0.052929  ...  0.985585  0.989322  0.993453
# 9997  0.046779  0.050423  0.054652  ...  0.997299  1.000036  1.003015
# 9998  0.045963  0.049480  0.053555  ...  0.987771  0.991560  0.995730
# 9999  0.046758  0.050417  0.054672  ...  1.012703  1.010231  1.007680
#
#           Mu94      Mu95      Mu96      Mu97      Mu98      Mu99     Mu100
# 0     1.005829  1.005684  1.005819  1.006310  1.007230  1.008654  1.010659
# 1     1.006324  1.006351  1.006425  1.006548  1.006725  1.006956  1.007247
# 2     1.001510  1.003095  1.004983  1.007214  1.009826  1.012858  1.016347
# 3     1.004740  1.006998  1.009540  1.012384  1.015547  1.019047  1.022900
# 4     1.008924  1.005628  1.002452  0.999484  0.996811  0.994521  0.992700
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  1.002243  1.000780  0.999469  0.998354  0.997476  0.996880  0.996608
# 9996  0.998008  1.003020  1.008521  1.014543  1.021117  1.028275  1.036050
# 9997  1.006259  1.009791  1.013632  1.017806  1.022334  1.027241  1.032548
# 9998  1.000289  1.005244  1.010602  1.016371  1.022558  1.029171  1.036217
# 9999  1.005114  1.002594  1.000182  0.997940  0.995931  0.994216  0.992859
#
# [10000 rows x 101 columns]

# %%
mu_cn_averaged.iloc[0, 1:]
# Out:
# Mu1      0.030473
# Mu2      0.032903
# Mu3      0.035245
# Mu4      0.037608
# Mu5      0.040101
#            ...
# Mu96     1.005819
# Mu97     1.006310
# Mu98     1.007230
# Mu99     1.008654
# Mu100    1.010659
# Name: 0, Length: 100, dtype: float64

# %%
systems_averaged
# Out:
#                                   System1  \
# 0             Cu2.8Te2-24173-R3/Cu1_2_118
# 1      Cu2.83Te2-orthor-53355-R2/Cu1_2_82
# 2      Cu2.83Te2-orthor-53355-R2/Cu2_2_91
# 3               Cu2.8Te2-24173-R1/Cu1_120
# 4       Cu2.83Te2-orthor-53355-R1/Cu2_400
# ...                                   ...
# 9995    Cu2.83Te2-orthor-53355-R1/Cu1_243
# 9996  Cu2.83Te2-orthor-53355-R1/Cu1_2_118
# 9997          Cu2.8Te2-24173-R3/Cu2_2_388
# 9998     Cu2.83Te2-orthor-53355-R1/Cu1_97
# 9999          Cu1.5Te-629332-R1/Cu2_2_243
#
#                                   System2  \
# 0            Cu1.5Te-629332-full/Cu2_2_82
# 1             Cu2.8Te2-24173-R1/Cu1_2_392
# 2              Cu2.8Te2-24173-R3/Cu1_2_82
# 3               Cu2.8Te2-24173-R2/Cu1_120
# 4       Cu2.83Te2-orthor-53355-R1/Cu2_119
# ...                                   ...
# 9995           Cu2.8Te2-24173-R1/Cu2_2_82
# 9996  Cu2.83Te2-orthor-53355-R3/Cu1_2_242
# 9997  Cu2.83Te2-orthor-53355-R1/Cu1_2_392
# 9998  Cu2.83Te2-orthor-53355-R3/Cu1_2_386
# 9999          Cu2.8Te2-24173-R3/Cu1_2_386
#
#                                   System3  \
# 0             Cu1.5Te-629332-R1/Cu1_2_118
# 1              Cu2.8Te2-24173-R3/Cu1_2_82
# 2             Cu1.5Te-629332-R1/Cu1_2_392
# 3     Cu2.83Te2-orthor-53355-R2/Cu2_2_242
# 4       Cu2.83Te2-orthor-53355-R3/Cu2_400
# ...                                   ...
# 9995  Cu2.83Te2-orthor-53355-R3/Cu1_2_118
# 9996            Cu1.5Te-629332-R3/Cu1_120
# 9997          Cu1.5Te-629332-R1/Cu1_2_399
# 9998             Cu2.8Te2-24173-R1/Cu1_97
# 9999            Cu2.8Te2-24173-R2/Cu2_119
#
#                                   System4  \
# 0        Cu2.83Te2-orthor-53355-R3/Cu1_84
# 1              Cu2.8Te2-24173-R2/Cu2_2_82
# 2     Cu2.83Te2-orthor-53355-R1/Cu1_2_392
# 3                Cu1.5Te-629332-R3/Cu1_84
# 4              Cu2.8Te2-24173-R1/Cu2_2_82
# ...                                   ...
# 9995           Cu2.8Te2-24173-R1/Cu2_2_91
# 9996                                 None
# 9997  Cu2.83Te2-orthor-53355-R2/Cu1_2_386
# 9998          Cu2.8Te2-24173-R1/Cu1_2_399
# 9999  Cu2.83Te2-orthor-53355-R2/Cu2_2_382
#
#                                   System5  \
# 0             Cu2.8Te2-24173-R3/Cu1_2_386
# 1        Cu2.83Te2-orthor-53355-R1/Cu2_82
# 2              Cu1.5Te-629332-R3/Cu2_2_97
# 3                                    None
# 4             Cu2.8Te2-24173-R1/Cu1_2_242
# ...                                   ...
# 9995  Cu2.83Te2-orthor-53355-R3/Cu1_2_399
# 9996                                 None
# 9997           Cu2.8Te2-24173-R3/Cu1_2_95
# 9998   Cu2.83Te2-orthor-53355-R3/Cu1_2_82
# 9999           Cu1.5Te-629332-R2/Cu2_2_82
#
#                                    System6                           System7  \
# 0              Cu1.5Te-629332-R2/Cu2_2_388          Cu2.8Te2-24173-R2/Cu1_84
# 1                                     None                              None
# 2      Cu2.83Te2-orthor-53355-R1/Cu1_2_242  Cu2.83Te2-orthor-53355-R2/Cu2_97
# 3                                     None                              None
# 4     Cu2.83Te2-orthor-53355-full/Cu1_2_82                              None
# ...                                    ...                               ...
# 9995     Cu2.83Te2-orthor-53355-R1/Cu2_242                              None
# 9996                                  None                              None
# 9997              Cu2.8Te2-24173-R2/Cu1_84        Cu1.5Te-629332-R2/Cu2_2_91
# 9998   Cu2.83Te2-orthor-53355-R1/Cu1_2_386                              None
# 9999           Cu2.8Te2-24173-R2/Cu1_2_101         Cu1.5Te-629332-R2/Cu2_365
#
#                                   System8                     System9  \
# 0             Cu1.5Te-629332-R1/Cu1_2_393                        None
# 1                                    None                        None
# 2     Cu2.83Te2-orthor-53355-R3/Cu1_2_101    Cu1.5Te-629332-R2/Cu2_96
# 3                                    None                        None
# 4                                    None                        None
# ...                                   ...                         ...
# 9995                                 None                        None
# 9996                                 None                        None
# 9997         Cu2.8Te2-24173-full/Cu2_2_82                        None
# 9998                                 None                        None
# 9999             Cu1.5Te-629332-R1/Cu1_84  Cu2.8Te2-24173-R2/Cu1_2_82
#
#                        System10
# 0                          None
# 1                          None
# 2     Cu1.5Te-629332-R1/Cu2_102
# 3                          None
# 4                          None
# ...                         ...
# 9995                       None
# 9996                       None
# 9997                       None
# 9998                       None
# 9999                       None
#
# [10000 rows x 10 columns]

# %%
weights_averaged
# Out:
#        Weight1   Weight2   Weight3   Weight4   Weight5   Weight6   Weight7  \
# 0     0.108816  0.413009  0.040033  0.160400  0.005740  0.147344  0.095637
# 1     0.073028  0.067102  0.261644  0.373929  0.224297       NaN       NaN
# 2     0.097752  0.075075  0.090922  0.311141  0.068120  0.119260  0.049559
# 3     0.315054  0.029593  0.352632  0.302721       NaN       NaN       NaN
# 4     0.041024  0.085454  0.564785  0.264449  0.036253  0.008036       NaN
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  0.088298  0.148692  0.104632  0.311060  0.008929  0.338389       NaN
# 9996  0.676706  0.230148  0.093146       NaN       NaN       NaN       NaN
# 9997  0.051751  0.013145  0.089923  0.311709  0.065372  0.373299  0.011226
# 9998  0.025804  0.334673  0.214706  0.075147  0.322014  0.027655       NaN
# 9999  0.394169  0.000607  0.001889  0.185412  0.009309  0.003687  0.284934
#
#        Weight8   Weight9  Weight10
# 0     0.029020       NaN       NaN
# 1          NaN       NaN       NaN
# 2     0.002113  0.027399  0.158659
# 3          NaN       NaN       NaN
# 4          NaN       NaN       NaN
# ...        ...       ...       ...
# 9995       NaN       NaN       NaN
# 9996       NaN       NaN       NaN
# 9997  0.083575       NaN       NaN
# 9998       NaN       NaN       NaN
# 9999  0.101662  0.018331       NaN
#
# [10000 rows x 10 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df = pd.read_csv('/Users/xinyuewang/Desktop/spectra_energy_mu.csv')
x= df['Energies (eV)']
x = x.values
y= mu_cn_averaged.iloc[9, 1:]
plt.plot(x,y)

# %%
from sklearn.model_selection import train_test_split
import sklearn.gaussian_process as gp
from sklearn.metrics import r2_score
def GPR_fit_curve(mu_cn_averaged):
    x = mu_cn_averaged.iloc[:, 1:]
    y = mu_cn_averaged.iloc[:,0:1]
    x_train,x_test,y_train,y_test=train_test_split(x.values,y.values,train_size=0.6,test_size=0.4,random_state=123)
    #x_train.values.reshape(-1,1)
    kernel = gp.kernels.ConstantKernel(1.0, (1e-1, 1e3)) * gp.kernels.RBF(10.0, (1e-3, 1e3))
    model = gp.GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=10, alpha=0.1, normalize_y=True)
    gpr = model.fit(x_train, y_train)
    print("score:")
    print(gpr.score(x_train, y_train))
    params = model.kernel_.get_params()
    print("params is :")
    print(params)
    y_pred, std = model.predict(x_test, return_std=True)
    MSE = ((y_pred-y_test)**2).mean()
    print(MSE)
    print('R-squared of training data is: '+"{:.3f}".format(r2_score(y_train,model.predict(x_train)))+', '+"{:.3f}".format(model.score(x_train,y_train)))
    print('R-squared of testing data is: '+"{:.3f}".format(r2_score(y_test,model.predict(x_test)))+', '+"{:.3f}".format(model.score(x_test,y_test)))
    fig, axs = plt.subplots(1,1,figsize=(15,20))
    axs.scatter(model.predict(x_test), y_test)
    axs.plot(np.linspace(8,11), np.linspace(8,11))
    axs.set_xlabel('Predicted')
    axs.set_ylabel('Actual')

# %%
GPR_fit_curve(mu_cn_averaged)
# Out:
# score:
# 0.9957518214540447
# params is :
# {'k1': 31.6**2, 'k2': RBF(length_scale=2.47), 'k1__constant_value': 999.9999999999998, 'k1__constant_value_bounds': (0.1, 1000.0), 'k2__length_scale': 2.4724467915223687, 'k2__length_scale_bounds': (0.001, 1000.0)}
# 0.001153791580379158
# R-squared of training data is: 0.996, 0.996
# R-squared of testing data is: 0.996, 0.996
